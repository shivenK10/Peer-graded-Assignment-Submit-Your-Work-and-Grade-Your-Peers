# %%
# Title: Peer-graded Assignment: Submit Your Work and Grade Your Peers

# %%
# Intoduction:
# Currently in my third year of B.E. Computer Engineering, I'm Shiven Khare, passionate about technology and programming. 
# Skilled in Python, C, C++, Angular (basics), HTML5, DSA, Operating Systems, DBMS and Web Development 
# I'm driven to explore and innovate within the tech space. Eager to connect and collaborate with like-minded professionals to 
# contribute to transformative projects.

# %%
# Data Science Languages:
# R
# RStudio
# Python
# Julia
# Java

# %%
# Data Science Libraries:
# Matplotlib
# Pandas
# NumPy

# %%
# Table of Data Science Tools

| Tool          | Description                                    |
|---------------|------------------------------------------------|
| Jupyter       | Interactive computing environment              |
| RStudio       | Integrated development environment for R       |
| Apache Spark  | Unified analytics engine for big data          |
| TensorFlow    | Open-source machine learning framework         |
| RapidMiner    | Data science platform for predictive analytics |
| MATLAB        | Numerical computing environment                |
| Excel         | Spreadsheet software                           |
| SAS           | Statistical software suite                     |
| KNIME         | Open-source data analytics platform            |
| Tableau       | Data visualization software                    |

# %%
Sure! Here is the combined markdown cell with examples of basic arithmetic operations in Python:

```markdown
# Arithmetic Expression Examples

In this section, we will explore some basic arithmetic operations in Python. Arithmetic expressions allow us to perform calculations and manipulate numerical data. Here are a few examples:

### Addition
The `+` operator is used to add two numbers.
```python
a = 5
b = 3
sum = a + b
print("Sum:", sum)
```
Output:
```
Sum: 8
```

### Subtraction
The `-` operator is used to subtract one number from another.
```python
a = 5
b = 3
difference = a - b
print("Difference:", difference)
```
Output:
```
Difference: 2
```

### Multiplication
The `*` operator is used to multiply two numbers.
```python
a = 5
b = 3
product = a * b
print("Product:", product)
```
Output:
```
Product: 15
```

### Division
The `/` operator is used to divide one number by another.
```python
a = 6
b = 3
quotient = a / b
print("Quotient:", quotient)
```
Output:
```
Quotient: 2.0
```

### Modulus
The `%` operator is used to find the remainder of the division of one number by another.
```python
a = 5
b = 3
remainder = a % b
print("Remainder:", remainder)
```
Output:
```
Remainder: 2
```

### Exponentiation
The `**` operator is used to raise one number to the power of another.
```python
a = 5
b = 3
power = a ** b
print("Power:", power)
```
Output:
```
Power: 125
```

These examples demonstrate basic arithmetic operations that you can perform in Python to manipulate numerical data.
```

# %%
# Objectives

The objectives of this notebook are as follows:

1. **Understand Data Science Languages:**
   - Learn about the various programming languages used in data science, such as Python and R.

2. **Explore Data Science Libraries:**
   - Familiarize yourself with popular data science libraries like Pandas, NumPy, and scikit-learn.

3. **Review Data Science Tools:**
   - Gain insights into essential data science tools such as Jupyter Notebook, RStudio, and Apache Spark.

4. **Practice Basic Arithmetic Operations:**
   - Perform and understand basic arithmetic operations such as addition, subtraction, multiplication, and division.

5. **Data Conversion Techniques:**
   - Learn to convert data between different units, such as minutes to hours.

6. **Share and Collaborate:**
   - Share the notebook on GitHub to collaborate with others and demonstrate your understanding of the course material.

# %%
# Author

This notebook was created by Shiven Khare as part of the final project for the Data Science by IBM on Coursera. If you have any questions or feedback, feel free to reach out.

# %%
# Multiplying and Adding Numbers

# Define two numbers
num1 = 7
num2 = 5

# Multiply the numbers
product = num1 * num2
print("Product:", product)

# Add the numbers
sum_result = num1 + num2
print("Sum:", sum_result)

# %%
# Converting Minutes to Hours

# Define the number of minutes
minutes = 150

# Convert minutes to hours
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
